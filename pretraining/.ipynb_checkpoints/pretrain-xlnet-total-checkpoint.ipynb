# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import spacy
import re
from tqdm import tqdm
import string

# %%
# STEP 1: load Note datasets
df_notes = pd.read_csv('/scratch/kh2383/MIMIC/1.4/NOTEEVENTS.csv')
# Out:
# /share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/ipython-6.2.1-py3.6.egg/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# STEP 2: Generate the cohort to pretrain on (here e.g. we only pretrian on physician and nursing notes) 
df_notes = df_notes[df_notes.CATEGORY.isin(['Respiratory ','Nursing','Nursing/Others'])]

# IMPORTANT: if you fine tune on the same dataset that you use for pretrain, you need to preclude the fine-tune test admissions 
df_test_ids = pd.read_csv('/scratch/kh2383/MechVent/data/test.csv').HADM_ID.unique()
df_notes_fold = df_notes[~df_notes.HADM_ID.isin(df_test_ids)]

# %%
# STEP 3: Preprocessing
def preprocess1(x):
    y=re.sub('\\[(.*?)\\]','',x) #remove de-identified brackets
    y=re.sub('[0-9]+\.','',y) #remove 1.2. since the segmenter segments based on this
    y=re.sub('dr\.','doctor',y)
    y=re.sub('m\.d\.','md',y)
    y=re.sub('admission date:','',y)
    y=re.sub('discharge date:','',y)
    y=re.sub('--|__|==','',y)
    
    # remove punctuation, digits, spaces
    #y = y.translate(str.maketrans("", "", string.punctuation))
    y = y.translate(str.maketrans("", "", string.digits))
    y = " ".join(y.split())
    return y

def preprocessing(df_notes): 
    df_notes['TEXT']=df_notes['TEXT'].fillna(' ')
    df_notes['TEXT']=df_notes['TEXT'].str.replace('\n',' ')
    df_notes['TEXT']=df_notes['TEXT'].str.replace('\r',' ')
    df_notes['TEXT']=df_notes['TEXT'].apply(str.strip)
    df_notes['TEXT']=df_notes['TEXT'].str.lower()

    df_notes['TEXT']=df_notes['TEXT'].apply(lambda x: preprocess1(x))
    
    return df_notes

df_notes_fold = preprocessing(df_notes_fold)

# %%
# STEP 4: Notes to Sentences
from spacy.lang.en import English
nlp = English()  # just the language with no model
nlp.add_pipe(nlp.create_pipe('sentencizer'))

# nlp praser may not work when there is only one token. In these cases, we just remove them as note that has length 1 usually is some random stuff

def toSentence(x):
    doc = nlp(x)
    text=[]
    try:
        for sent in doc.sents:
            st=str(sent).strip() 
            if len(st)<20:
                #a lot of abbreviation is segmented as one line. But these are all describing the previous things
                #so I attached it to the sentence before
                if len(text)!=0:
                    text[-1]=' '.join((text[-1],st))
                else:
                    text=[st]
            else:
                text.append((st))
    except:
        print('single word notes ignored')
    return text

pretrain_sent=df_notes_fold['TEXT'].apply(lambda x: toSentence(x))
# Out:
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored
# single word notes ignored

# %%
# STEP 5: Create Pretraining File
file=open('/scratch/kh2383/MechVent/data/clinical_sentences_pretrain_xlnet_total.txt','w')
pretrain_sent = pretrain_sent.values
for i in (range(len(pretrain_sent))):
    if len(pretrain_sent[i]) > 0:
        # remove the one token note
        note = pretrain_sent[i]
        for sent in note:
            file.write(sent+'\n')
        file.write('\n')

# %%
# STEP 6: Download the Implementations and Initial Checkpoint with the SentencePiece Model and Vocab 
# Github Repo:
# XLNet: git clone https://github.com/zihangdai/xlnet.git
# Model: 
# XLNet-Base: https://storage.googleapis.com/xlnet/released_models/cased_L-12_H-768_A-12.zip

# %%
# STEP 7: Generate Pretraining Tensorflow TF_Records
# For Clinical XLNet
import os
os.chdir('./xlnet/')
# !python data_utils.py \
    --bsz_per_host=8 \
    --num_core_per_host=1 \
    --seq_len=512 \
    --reuse_len=256 \
    --input_glob=/scratch/kh2383/MechVent/data/clinical_sentences_pretrain_xlnet_total.txt \
    --save_dir=/scratch/kh2383/MechVent/data/xlnet_tfrecord_total/ \
    --num_passes=5 \
    --bi_data=True \
    --sp_path=/scratch/kh2383/clibert/xlnet_cased_L-12_H-768_A-12/spiece.model \
    --mask_alpha=6 \
    --mask_beta=1 \
    --num_predict=85
# Out:
# I1225 12:41:57.235386 47871649542784 data_utils.py:211] Use glob: /scratch/kh2383/MechVent/data/clinical_sentences_pretrain_xlnet_total.txt
# I1225 12:41:57.236729 47871649542784 data_utils.py:212] Find 1 files: ['/scratch/kh2383/MechVent/data/clinical_sentences_pretrain_xlnet_total.txt']
# I1225 12:41:57.236943 47871649542784 data_utils.py:220] Task 0 process 1 files: ['/scratch/kh2383/MechVent/data/clinical_sentences_pretrain_xlnet_total.txt']
# I1225 12:41:57.405687 47871649542784 data_utils.py:89] Processing /scratch/kh2383/MechVent/data/clinical_sentences_pretrain_xlnet_total.txt
# I1225 12:41:57.406338 47871649542784 data_utils.py:92] Loading line 0
# I1225 12:42:09.445044 47871649542784 data_utils.py:92] Loading line 100000
# I1225 12:42:20.928989 47871649542784 data_utils.py:92] Loading line 200000
# I1225 12:42:32.285392 47871649542784 data_utils.py:92] Loading line 300000
# I1225 12:42:43.433550 47871649542784 data_utils.py:92] Loading line 400000
# I1225 12:42:54.533169 47871649542784 data_utils.py:92] Loading line 500000
# I1225 12:43:05.603631 47871649542784 data_utils.py:92] Loading line 600000
# I1225 12:43:16.537321 47871649542784 data_utils.py:92] Loading line 700000
# I1225 12:43:27.522247 47871649542784 data_utils.py:92] Loading line 800000
# I1225 12:43:38.739186 47871649542784 data_utils.py:92] Loading line 900000
# I1225 12:43:50.019648 47871649542784 data_utils.py:92] Loading line 1000000
# I1225 12:44:01.004997 47871649542784 data_utils.py:92] Loading line 1100000
# I1225 12:44:11.921352 47871649542784 data_utils.py:92] Loading line 1200000
# I1225 12:44:22.668030 47871649542784 data_utils.py:92] Loading line 1300000
# I1225 12:44:33.657568 47871649542784 data_utils.py:92] Loading line 1400000
# I1225 12:44:44.529116 47871649542784 data_utils.py:92] Loading line 1500000
# I1225 12:44:55.591599 47871649542784 data_utils.py:92] Loading line 1600000
# I1225 12:45:06.333030 47871649542784 data_utils.py:92] Loading line 1700000
# I1225 12:45:17.048477 47871649542784 data_utils.py:92] Loading line 1800000
# I1225 12:45:27.778705 47871649542784 data_utils.py:92] Loading line 1900000
# I1225 12:45:38.486504 47871649542784 data_utils.py:92] Loading line 2000000
# I1225 12:45:49.207587 47871649542784 data_utils.py:92] Loading line 2100000
# I1225 12:46:00.285442 47871649542784 data_utils.py:92] Loading line 2200000
# %%
# !python train_gpu.py \
    --record_info_dir=/scratch/kh2383/MechVent/data/xlnet_tfrecord_total/tfrecords/ \
    --model_dir=/scratch/kh2383/MechVent/model/xlnet_model/ \
    --init_checkpoint=/scratch/kh2383/MechVent/model/xlnet_model/model.ckpt \
    --train_batch_size=8 \
    --seq_len=512 \
    --reuse_len=256 \
    --mem_len=384 \
    --perm_size=256 \
    --n_layer=12 \
    --d_model=768 \
    --d_embed=768 \
    --n_head=12 \
    --d_head=64 \
    --d_inner=3072 \
    --untie_r=True \
    --mask_alpha=6 \
    --mask_beta=1 \
    --num_predict=85 \
    --num_hosts=1 \
    --num_core_per_host=2 \
    --train_steps=400000 \
    --iterations=500 \
    --save_steps=5000
# Out:
# I1225 13:55:12.645989 47630971126400 train_gpu.py:328] n_token 32000
# I1225 13:55:12.651739 47630971126400 data_utils.py:795] Use the following tfrecord dirs: ['/scratch/kh2383/MechVent/data/xlnet_tfrecord_total/tfrecords/']
# I1225 13:55:12.652017 47630971126400 data_utils.py:799] [0] Record glob: /scratch/kh2383/MechVent/data/xlnet_tfrecord_total/tfrecords/record_info-train-*.bsz-8.seqlen-512.reuse-256.bi.alpha-6.beta-1.fnp-85.json
# I1225 13:55:13.006576 47630971126400 data_utils.py:809] ['/scratch/kh2383/MechVent/data/xlnet_tfrecord/tfrecords/record_info-train-0-0.bsz-8.seqlen-512.reuse-256.uncased.bi.alpha-6.beta-1.fnp-85.json']
# I1225 13:55:13.006993 47630971126400 data_utils.py:812] [0] Num of record info path: 1
# I1225 13:55:13.035062 47630971126400 data_utils.py:845] [Dir 0] Number of chosen batches: 98747
# I1225 13:55:13.035315 47630971126400 data_utils.py:847] [Dir 0] Number of chosen files: 1
# I1225 13:55:13.035436 47630971126400 data_utils.py:848] ['/scratch/kh2383/MechVent/data/xlnet_tfrecord_total/tfrecords/train-0-0.bsz-8.seqlen-512.reuse-256.uncased.bi.alpha-6.beta-1.fnp-85.tfrecords']
# I1225 13:55:13.035557 47630971126400 data_utils.py:855] Total number of batches: 98747
# I1225 13:55:13.036212 47630971126400 data_utils.py:857] Total number of files: 1
# I1225 13:55:13.036329 47630971126400 data_utils.py:858] ['/scratch/kh2383/MechVent/data/xlnet_tfrecord_total/tfrecords/train-0-0.bsz-8.seqlen-512.reuse-256.uncased.bi.alpha-6.beta-1.fnp-85.tfrecords']
# I1225 13:55:13.036448 47630971126400 train_gpu.py:205] num of batches 98747
# I1225 13:55:13.036580 47630971126400 data_utils.py:555] Host 0 handles 1 files
# I1225 13:55:13.528424 47630971126400 data_utils.py:744] label: Tensor("Cast_6:0", shape=(1,), dtype=int32)
# I1225 13:55:13.528835 47630971126400 data_utils.py:744] seg_id: Tensor("Cast_7:0", shape=(512,), dtype=int32)
# I1225 13:55:13.528996 47630971126400 data_utils.py:744] target_mapping: Tensor("Reshape_4:0", shape=(85, 512), dtype=float32)
# I1225 13:55:13.529146 47630971126400 data_utils.py:744] target: Tensor("Cast_8:0", shape=(85,), dtype=int32)
# I1225 13:55:13.529280 47630971126400 data_utils.py:744] target_mask: Tensor("Reshape_6:0", shape=(85,), dtype=float32)
# I1225 13:55:13.529410 47630971126400 data_utils.py:744] perm_mask: Tensor("Reshape_7:0", shape=(512, 512), dtype=float32)
# I1225 13:55:13.529547 47630971126400 data_utils.py:744] input_k: Tensor("Cast_9:0", shape=(512,), dtype=int32)
# I1225 13:55:13.529677 47630971126400 data_utils.py:744] input_q: Tensor("Reshape_9:0", shape=(512,), dtype=float32)
# I1225 13:55:13.650044 47630971126400 modeling.py:453] memory input [<tf.Tensor 'Placeholder:0' shape=(384, 4, 768) dtype=float32>, <tf.Tensor 'Placeholder_1:0' shape=(384, 4, 768) dtype=float32>, <tf.Tensor 'Placeholder_2:0' shape=(384, 4, 768) dtype=float32>, <tf.Tensor 'Placeholder_3:0' shape=(384, 4, 768) dtype=float32>, <tf.Tensor 'Placeholder_4:0' shape=(384, 4, 768) dtype=float32>, <tf.Tensor 'Placeholder_5:0' shape=(384, 4, 768) dtype=float32>, <tf.Tensor 'Placeholder_6:0' shape=(384, 4, 768) dtype=float32>, <tf.Tensor 'Placeholder_7:0' shape=(384, 4, 768) dtype=float32>, <tf.Tensor 'Placeholder_8:0' shape=(384, 4, 768) dtype=float32>, <tf.Tensor 'Placeholder_9:0' shape=(384, 4, 768) dtype=float32>, <tf.Tensor 'Placeholder_10:0' shape=(384, 4, 768) dtype=float32>, <tf.Tensor 'Placeholder_11:0' shape=(384, 4, 768) dtype=float32>]
# I1225 13:55:13.650468 47630971126400 modeling.py:455] Use float type <dtype: 'float32'>
# W1225 13:55:13.663163 47630971126400 deprecation.py:323] From /home/kh2383/pytorch-gpu/py3.6.3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# W1225 13:55:13.795295 47630971126400 deprecation.py:323] From /home/kh2383/MechVent/pretraining/xlnet/modeling.py:535: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dropout instead.
# W1225 13:55:13.797203 47630971126400 deprecation.py:506] From /home/kh2383/pytorch-gpu/py3.6.3/lib/python3.6/site-packages/tensorflow/python/keras/layers/core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
#
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# W1225 13:55:19.771000 47630971126400 deprecation.py:323] From /home/kh2383/MechVent/pretraining/xlnet/modeling.py:67: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# I1225 13:55:24.960698 47630971126400 train_gpu.py:143] #params: 116750336
# W1225 13:55:25.072123 47630971126400 deprecation.py:323] From /home/kh2383/pytorch-gpu/py3.6.3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# I1225 13:55:32.326916 47630971126400 modeling.py:453] memory input [<tf.Tensor 'Placeholder_12:0' shape=(384, 4, 768) dtype=float32>, <tf.Tensor 'Placeholder_13:0' shape=(384, 4, 768) dtype=float32>, <tf.Tensor 'Placeholder_14:0' shape=(384, 4, 768) dtype=float32>, <tf.Tensor 'Placeholder_15:0' shape=(384, 4, 768) dtype=float32>, <tf.Tensor 'Placeholder_16:0' shape=(384, 4, 768) dtype=float32>, <tf.Tensor 'Placeholder_17:0' shape=(384, 4, 768) dtype=float32>, <tf.Tensor 'Placeholder_18:0' shape=(384, 4, 768) dtype=float32>, <tf.Tensor 'Placeholder_19:0' shape=(384, 4, 768) dtype=float32>, <tf.Tensor 'Placeholder_20:0' shape=(384, 4, 768) dtype=float32>, <tf.Tensor 'Placeholder_21:0' shape=(384, 4, 768) dtype=float32>, <tf.Tensor 'Placeholder_22:0' shape=(384, 4, 768) dtype=float32>, <tf.Tensor 'Placeholder_23:0' shape=(384, 4, 768) dtype=float32>]
# I1225 13:55:32.327224 47630971126400 modeling.py:455] Use float type <dtype: 'float32'>
# I1225 13:55:36.957721 47630971126400 train_gpu.py:143] #params: 116750336
# W1225 13:55:44.545580 47630971126400 deprecation.py:323] From /home/kh2383/pytorch-gpu/py3.6.3/lib/python3.6/site-packages/tensorflow/python/training/learning_rate_decay_v2.py:321: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# I1225 13:55:47.470240 47630971126400 model_utils.py:71] Initialize from the ckpt /scratch/kh2383/MechVent/model/xlnet_model/model.ckpt
# I1225 13:55:49.415961 47630971126400 model_utils.py:85] **** Global Variables ****
# I1225 13:55:49.416203 47630971126400 model_utils.py:91]   name = model/transformer/r_w_bias:0, shape = (12, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.416302 47630971126400 model_utils.py:91]   name = model/transformer/r_r_bias:0, shape = (12, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.416387 47630971126400 model_utils.py:91]   name = model/transformer/word_embedding/lookup_table:0, shape = (32000, 768), *INIT_FROM_CKPT*
# I1225 13:55:49.416467 47630971126400 model_utils.py:91]   name = model/transformer/mask_emb/mask_emb:0, shape = (1, 1, 768), *INIT_FROM_CKPT*
# I1225 13:55:49.416544 47630971126400 model_utils.py:91]   name = model/transformer/r_s_bias:0, shape = (12, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.416620 47630971126400 model_utils.py:91]   name = model/transformer/seg_embed:0, shape = (12, 2, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.416698 47630971126400 model_utils.py:91]   name = model/transformer/layer_0/rel_attn/k/kernel:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49
model_utils.py:91]   name = model/transformer/layer_8/rel_attn/k/kernel:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.428186 47630971126400 model_utils.py:91]   name = model/transformer/layer_8/rel_attn/v/kernel:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.428293 47630971126400 model_utils.py:91]   name = model/transformer/layer_8/rel_attn/r/kernel:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.428400 47630971126400 model_utils.py:91]   name = model/transformer/layer_8/rel_attn/q/kernel:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.428507 47630971126400 model_utils.py:91]   name = model/transformer/layer_8/rel_attn/o/kernel:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.428614 47630971126400 model_utils.py:91]   name = model/transformer/layer_8/rel_attn/LayerNorm/beta:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.428715 47630971126400 model_utils.py:91]   name = model/transformer/layer_8/rel_attn/LayerNorm/gamma:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.428821 47630971126400 model_utils.py:91]   name = model/transformer/layer_8/ff/layer_1/kernel:0, shape = (768, 3072), *INIT_FROM_CKPT*
# I1225 13:55:49.428928 47630971126400 model_utils.py:91]   name = model/transformer/layer_8/ff/layer_1/bias:0, shape = (3072,), *INIT_FROM_CKPT*
# I1225 13:55:49.429029 47630971126400 model_utils.py:91]   name = model/transformer/layer_8/ff/layer_2/kernel:0, shape = (3072, 768), *INIT_FROM_CKPT*
# I1225 13:55:49.429134 47630971126400 model_utils.py:91]   name = model/transformer/layer_8/ff/layer_2/bias:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.429234 47630971126400 model_utils.py:91]   name = model/transformer/layer_8/ff/LayerNorm/beta:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.429335 47630971126400 model_utils.py:91]   name = model/transformer/layer_8/ff/LayerNorm/gamma:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.429434 47630971126400 model_utils.py:91]   name = model/transformer/layer_9/rel_attn/k/kernel:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.429540 47630971126400 model_utils.py:91]   name = model/transformer/layer_9/rel_attn/v/kernel:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.429650 47630971126400 model_utils.py:91]   name = model/transformer/layer_9/rel_attn/r/kernel:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.429757 47630971126400 model_utils.py:91]   name = model/transformer/layer_9/rel_attn/q/kernel:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.429874 47630971126400 model_utils.py:91]   name = model/transformer/layer_9/rel_attn/o/kernel:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.429981 47630971126400 model_utils.py:91]   name = model/transformer/layer_9/rel_attn/LayerNorm/beta:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.430082 47630971126400 model_utils.py:91]   name = model/transformer/layer_9/rel_attn/LayerNorm/gamma:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.430182 47630971126400 model_utils.py:91]   name = model/transformer/layer_9/ff/layer_1/kernel:0, shape = (768, 3072), *INIT_FROM_CKPT*
# I1225 13:55:49.430288 47630971126400 model_utils.py:91]   name = model/transformer/layer_9/ff/layer_1/bias:0, shape = (3072,), *INIT_FROM_CKPT*
# I1225 13:55:49.430390 47630971126400 model_utils.py:91]   name = model/transformer/layer_9/ff/layer_2/kernel:0, shape = (3072, 768), *INIT_FROM_CKPT*
# I1225 13:55:49.430495 47630971126400 model_utils.py:91]   name = model/transformer/layer_9/ff/layer_2/bias:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.430596 47630971126400 model_utils.py:91]   name = model/transformer/layer_9/ff/LayerNorm/beta:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.430696 47630971126400 model_utils.py:91]   name = model/transformer/layer_9/ff/LayerNorm/gamma:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.430794 47630971126400 model_utils.py:91]   name = model/transformer/layer_10/rel_attn/k/kernel:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.430911 47630971126400 model_utils.py:91]   name = model/transformer/layer_10/rel_attn/v/kernel:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.431017 47630971126400 model_utils.py:91]   name = model/transformer/layer_10/rel_attn/r/kernel:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.431123 47630971126400 model_utils.py:91]   name = model/transformer/layer_10/rel_attn/q/kernel:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.431231 47630971126400 model_utils.py:91]   name = model/transformer/layer_10/rel_attn/o/kernel:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.431337 47630971126400 model_utils.py:91]   name = model/transformer/layer_10/rel_attn/LayerNorm/beta:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.431438 47630971126400 model_utils.py:91]   name = model/transformer/layer_10/rel_attn/LayerNorm/gamma:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.431539 47630971126400 model_utils.py:91]   name = model/transformer/layer_10/ff/layer_1/kernel:0, shape = (768, 3072), *INIT_FROM_CKPT*
# I1225 13:55:49.431645 47630971126400 model_utils.py:91]   name = model/transformer/layer_10/ff/layer_1/bias:0, shape = (3072,), *INIT_FROM_CKPT*
# I1225 13:55:49.431746 47630971126400 model_utils.py:91]   name = model/transformer/layer_10/ff/layer_2/kernel:0, shape = (3072, 768), *INIT_FROM_CKPT*
# I1225 13:55:49.431859 47630971126400 model_utils.py:91]   name = model/transformer/layer_10/ff/layer_2/bias:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.431960 47630971126400 model_utils.py:91]   name = model/transformer/layer_10/ff/LayerNorm/beta:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.432062 47630971126400 model_utils.py:91]   name = model/transformer/layer_10/ff/LayerNorm/gamma:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.432162 47630971126400 model_utils.py:91]   name = model/transformer/layer_11/rel_attn/k/kernel:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.432269 47630971126400 model_utils.py:91]   name = model/transformer/layer_11/rel_attn/v/kernel:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.432374 47630971126400 model_utils.py:91]   name = model/transformer/layer_11/rel_attn/r/kernel:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.432482 47630971126400 model_utils.py:91]   name = model/transformer/layer_11/rel_attn/q/kernel:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.432589 47630971126400 model_utils.py:91]   name = model/transformer/layer_11/rel_attn/o/kernel:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.432697 47630971126400 model_utils.py:91]   name = model/transformer/layer_11/rel_attn/LayerNorm/beta:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.432796 47630971126400 model_utils.py:91]   name = model/transformer/layer_11/rel_attn/LayerNorm/gamma:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.432904 47630971126400 model_utils.py:91]   name = model/transformer/layer_11/ff/layer_1/kernel:0, shape = (768, 3072), *INIT_FROM_CKPT*
# I1225 13:55:49.433009 47630971126400 model_utils.py:91]   name = model/transformer/layer_11/ff/layer_1/bias:0, shape = (3072,), *INIT_FROM_CKPT*
# I1225 13:55:49.433110 47630971126400 model_utils.py:91]   name = model/transformer/layer_11/ff/layer_2/kernel:0, shape = (3072, 768), *INIT_FROM_CKPT*
# I1225 13:55:49.433214 47630971126400 model_utils.py:91]   name = model/transformer/layer_11/ff/layer_2/bias:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.433315 47630971126400 model_utils.py:91]   name = model/transformer/layer_11/ff/LayerNorm/beta:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.433415 47630971126400 model_utils.py:91]   name = model/transformer/layer_11/ff/LayerNorm/gamma:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.433516 47630971126400 model_utils.py:91]   name = model/lm_loss/bias:0, shape = (32000,), *INIT_FROM_CKPT*
# I1225 13:55:49.433617 47630971126400 model_utils.py:91]   name = global_step:0, shape = (), *INIT_FROM_CKPT*
# I1225 13:55:49.433720 47630971126400 model_utils.py:91]   name = beta1_power:0, shape = (), *INIT_FROM_CKPT*
# I1225 13:55:49.433825 47630971126400 model_utils.py:91]   name = beta2_power:0, shape = (), *INIT_FROM_CKPT*
# I1225 13:55:49.433927 47630971126400 model_utils.py:91]   name = model/transformer/r_w_bias/Adam:0, shape = (12, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.434032 47630971126400 model_utils.py:91]   name = model/transformer/r_w_bias/Adam_1:0, shape = (12, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.434139 47630971126400 model_utils.py:91]   name = model/transformer/r_r_bias/Adam:0, shape = (12, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.434249 47630971126400 model_utils.py:91]   name = model/transformer/r_r_bias/Adam_1:0, shape = (12, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.434355 47630971126400 model_utils.py:91]   name = model/transformer/word_embedding/lookup_table/Adam:0, shape = (32000, 768), *INIT_FROM_CKPT*
# I1225 13:55:49.434460 47630971126400 model_utils.py:91]   name = model/transformer/word_embedding/lookup_table/Adam_1:0, shape = (32000, 768), *INIT_FROM_CKPT*
# I1225 13:55:49.434564 47630971126400 model_utils.py:91]   name = model/transformer/mask_emb/mask_emb/Adam:0, shape = (1, 1, 768), *INIT_FROM_CKPT*
# I1225 13:55:49.434669 47630971126400 model_utils.py:91]   name = model/transformer/mask_emb/mask_emb/Adam_1:0, shape = (1, 1, 768), *INIT_FROM_CKPT*
# I1225 13:55:49.434776 47630971126400 model_utils.py:91]   name = model/transformer/r_s_bias/Adam:0, shape = (12, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.434888 47630971126400 model_utils.py:91]   name = model/transformer/r_s_bias/Adam_1:0, shape = (12, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.434994 47630971126400 model_utils.py:91]   name = model/transformer/seg_embed/Adam:0, shape = (12, 2, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.435101 47630971126400 model_utils.py:91]   name = model/transformer/seg_embed/Adam_1:0, shape = (12, 2, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.435208 47630971126400 model_utils.py:91]   name = model/transformer/layer_0/rel_attn/k/kernel/Adam:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.435314 47630971126400 model_utils.py:91]   name = model/transformer/layer_0/rel_attn/k/kernel/Adam_1:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.435420 47630971126400 model_utils.py:91]   name = model/transformer/layer_0/rel_attn/v/kernel/Adam:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.435526 47630971126400 model_utils.py:91]   name = model/transformer/layer_0/rel_attn/v/kernel/Adam_1:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.435632 47630971126400 model_utils.py:91]   name = model/transformer/layer_0/rel_attn/r/kernel/Adam:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.435738 47630971126400 model_utils.py:91]   name = model/transformer/layer_0/rel_attn/r/kernel/Adam_1:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.435853 47630971126400 model_utils.py:91]   name = model/transformer/layer_0/rel_attn/q/kernel/Adam:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.435961 47630971126400 model_utils.py:91]   name = model/transformer/layer_0/rel_attn/q/kernel/Adam_1:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.436068 47630971126400 model_utils.py:91]   name = model/transformer/layer_0/rel_attn/o/kernel/Adam:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.436173 47630971126400 model_utils.py:91]   name = model/transformer/layer_0/rel_attn/o/kernel/Adam_1:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.436281 47630971126400 model_utils.py:91]   name = model/transformer/layer_0/rel_attn/LayerNorm/beta/Adam:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.436382 47630971126400 model_utils.py:91]   name = model/transformer/layer_0/rel_attn/LayerNorm/beta/Adam_1:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.436483 47630971126400 model_utils.py:91]   name = model/transformer/layer_0/rel_attn/LayerNorm/gamma/Adam:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.436583 47630971126400 model_utils.py:91]   name = model/transformer/layer_0/rel_attn/LayerNorm/gamma/Adam_1:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.436684 47630971126400 model_utils.py:91]   name = model/transformer/layer_0/ff/layer_1/kernel/Adam:0, shape = (768, 3072), *INIT_FROM_CKPT*
# I1225 13:55:49.436788 47630971126400 model_utils.py:91]   name = model/transformer/layer_0/ff/layer_1/kernel/Adam_1:0, shape = (768, 3072), *INIT_FROM_CKPT*
# I1225 13:55:49.436903 47630971126400 model_utils.py:91]   name = model/transformer/layer_0/ff/layer_1/bias/Adam:0, shape = (3072,), *INIT_FROM_CKPT*
# I1225 13:55:49.437004 47630971126400 model_utils.py:91]   name = model/transformer/layer_0/ff/layer_1/bias/Adam_1:0, shape = (3072,), *INIT_FROM_CKPT*
# I1225 13:55:49.437105 47630971126400 model_utils.py:91]   name = model/transformer/layer_0/ff/layer_2/kernel/Adam:0, shape = (3072, 768), *INIT_FROM_CKPT*
# I1225 13:55:49.437220 47630971126400 model_utils.py:91]   name = model/transformer/layer_0/ff/layer_2/kernel/Adam_1:0, shape = (3072, 768), *INIT_FROM_CKPT*
# I1225 13:55:49.437322 47630971126400 model_utils.py:91]   name = model/transformer/layer_0/ff/layer_2/bias/Adam:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.437418 47630971126400 model_utils.py:91]   name = model/transformer/layer_0/ff/layer_2/bias/Adam_1:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.437514 47630971126400 model_utils.py:91]   name = model/transformer/layer_0/ff/LayerNorm/beta/Adam:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.437610 47630971126400 model_utils.py:91]   name = model/transformer/layer_0/ff/LayerNorm/beta/Adam_1:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.437706 47630971126400 model_utils.py:91]   name = model/transformer/layer_0/ff/LayerNorm/gamma/Adam:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.437806 47630971126400 model_utils.py:91]   name = model/transformer/layer_0/ff/LayerNorm/gamma/Adam_1:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.437905 47630971126400 model_utils.py:91]   name = model/transformer/layer_1/rel_attn/k/kernel/Adam:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.438008 47630971126400 model_utils.py:91]   name = model/transformer/layer_1/rel_attn/k/kernel/Adam_1:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.438111 47630971126400 model_utils.py:91]   name = model/transformer/layer_1/rel_attn/v/kernel/Adam:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.438218 47630971126400 model_utils.py:91]   name = model/transformer/layer_1/rel_attn/v/kernel/Adam_1:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.438321 47630971126400 model_utils.py:91]   name = model/transformer/layer_1/rel_attn/r/kernel/Adam:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.438422 47630971126400 model_utils.py:91]   name = model/transformer/layer_1/rel_attn/r/kernel/Adam_1:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.438526 47630971126400 model_utils.py:91]   name = model/transformer/layer_1/rel_attn/q/kernel/Adam:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.438628 47630971126400 model_utils.py:91]   name = model/transformer/layer_1/rel_attn/q/kernel/Adam_1:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.438730 47630971126400 model_utils.py:91]   name = model/transformer/layer_1/rel_attn/o/kernel/Adam:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.438840 47630971126400 model_utils.py:91]   name = model/transformer/layer_1/rel_attn/o/kernel/Adam_1:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.438946 47630971126400 model_utils.py:91]   name = model/transformer/layer_1/rel_attn/LayerNorm/beta/Adam:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.439046 47630971126400 model_utils.py:91]   name = model/transformer/layer_1/rel_attn/LayerNorm/beta/Adam_1:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.439143 47630971126400 model_utils.py:91]   name = model/transformer/layer_1/rel_attn/LayerNorm/gamma/Adam:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.439239 47630971126400 model_utils.py:91]   name = model/transformer/layer_1/rel_attn/LayerNorm/gamma/Adam_1:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.439334 47630971126400 model_utils.py:91]   name = model/transformer/layer_1/ff/layer_1/kernel/Adam:0, shape = (768, 3072), *INIT_FROM_CKPT*
# I1225 13:55:49.439436 47630971126400 model_utils.py:91]   name = model/transformer/layer_1/ff/layer_1/kernel/Adam_1:0, shape = (768, 3072), *INIT_FROM_CKPT*
# I1225 13:55:49.439539 47630971126400 model_utils.py:91]   name = model/transformer/layer_1/ff/layer_1/bias/Adam:0, shape = (3072,), *INIT_FROM_CKPT*
# I1225 13:55:49.439635 47630971126400 model_utils.py:91]   name = model/transformer/layer_1/ff/layer_1/bias/Adam_1:0, shape = (3072,), *INIT_FROM_CKPT*
# I1225 13:55:49.439731 47630971126400 model_utils.py:91]   name = model/transformer/layer_1/ff/layer_2/kernel/Adam:0, shape = (3072, 768), *INIT_FROM_CKPT*
# I1225 13:55:49.439842 47630971126400 model_utils.py:91]   name = model/transformer/layer_1/ff/layer_2/kernel/Adam_1:0, shape = (3072, 768), *INIT_FROM_CKPT*
# I1225 13:55:49.439946 47630971126400 model_utils.py:91]   name = model/transformer/layer_1/ff/layer_2/bias/Adam:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.440043 47630971126400 model_utils.py:91]   name = model/transformer/layer_1/ff/layer_2/bias/Adam_1:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.440138 47630971126400 model_utils.py:91]   name = model/transformer/layer_1/ff/LayerNorm/beta/Adam:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.440236 47630971126400 model_utils.py:91]   name = model/transformer/layer_1/ff/LayerNorm/beta/Adam_1:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.440333 47630971126400 model_utils.py:91]   name = model/transformer/layer_1/ff/LayerNorm/gamma/Adam:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.440428 47630971126400 model_utils.py:91]   name = model/transformer/layer_1/ff/LayerNorm/gamma/Adam_1:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.440523 47630971126400 model_utils.py:91]   name = model/transformer/layer_2/rel_attn/k/kernel/Adam:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.440625 47630971126400 model_utils.py:91]   name = model/transformer/layer_2/rel_attn/k/kernel/Adam_1:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.440728 47630971126400 model_utils.py:91]   name = model/transformer/layer_2/rel_attn/v/kernel/Adam:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.440836 47630971126400 model_utils.py:91]   name = model/transformer/layer_2/rel_attn/v/kernel/Adam_1:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.440940 47630971126400 model_utils.py:91]   name = model/transformer/layer_2/rel_attn/r/kernel/Adam:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.441043 47630971126400 model_utils.py:91]   name = model/transformer/layer_2/rel_attn/r/kernel/Adam_1:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.441146 47630971126400 model_utils.py:91]   name = model/transformer/layer_2/rel_attn/q/kernel/Adam:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.441249 47630971126400 model_utils.py:91]   name = model/transformer/layer_2/rel_attn/q/kernel/Adam_1:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.441351 47630971126400 model_utils.py:91]   name = model/transformer/layer_2/rel_attn/o/kernel/Adam:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.441454 47630971126400 model_utils.py:91]   name = model/transformer/layer_2/rel_attn/o/kernel/Adam_1:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.441557 47630971126400 model_utils.py:91]   name = model/transformer/layer_2/rel_attn/LayerNorm/beta/Adam:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.441653 47630971126400 model_utils.py:91]   name = model/transformer/layer_2/rel_attn/LayerNorm/beta/Adam_1:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.441750 47630971126400 model_utils.py:91]   name = model/transformer/layer_2/rel_attn/LayerNorm/gamma/Adam:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.441851 47630971126400 model_utils.py:91]   name = model/transformer/layer_2/rel_attn/LayerNorm/gamma/Adam_1:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.441948 47630971126400 model_utils.py:91]   name = model/transformer/layer_2/ff/layer_1/kernel/Adam:0, shape = (768, 3072), *INIT_FROM_CKPT*
# I1225 13:55:49.442049 47630971126400 model_utils.py:91]   name = model/transformer/layer_2/ff/layer_1/kernel/Adam_1:0, shape = (768, 3072), *INIT_FROM_CKPT*
# I1225 13:55:49.442151 47630971126400 model_utils.py:91]   name = model/transformer/layer_2/ff/layer_1/bias/Adam:0, shape = (3072,), *INIT_FROM_CKPT*
# I1225 13:55:49.442249 47630971126400 model_utils.py:91]   name = model/transformer/layer_2/ff/layer_1/bias/Adam_1:0, shape = (3072,), *INIT_FROM_CKPT*
# I1225 13:55:49.442345 47630971126400 model_utils.py:91]   name = model/transformer/layer_2/ff/layer_2/kernel/Adam:0, shape = (3072, 768), *INIT_FROM_CKPT*
# I1225 13:55:49.442446 47630971126400 model_utils.py:91]   name = model/transformer/layer_2/ff/layer_2/kernel/Adam_1:0, shape = (3072, 768), *INIT_FROM_CKPT*
# I1225 13:55:49.442548 47630971126400 model_utils.py:91]   name = model/transformer/layer_2/ff/layer_2/bias/Adam:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.442645 47630971126400 model_utils.py:91]   name = model/transformer/layer_2/ff/layer_2/bias/Adam_1:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.442740 47630971126400 model_utils.py:91]   name = model/transformer/layer_2/ff/LayerNorm/beta/Adam:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.442839 47630971126400 model_utils.py:91]   name = model/transformer/layer_2/ff/LayerNorm/beta/Adam_1:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.442937 47630971126400 model_utils.py:91]   name = model/transformer/layer_2/ff/LayerNorm/gamma/Adam:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.443032 47630971126400 model_utils.py:91]   name = model/transformer/layer_2/ff/LayerNorm/gamma/Adam_1:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.443128 47630971126400 model_utils.py:91]   name = model/transformer/layer_3/rel_attn/k/kernel/Adam:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.443235 47630971126400 model_utils.py:91]   name = model/transformer/layer_3/rel_attn/k/kernel/Adam_1:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.443339 47630971126400 model_utils.py:91]   name = model/transformer/layer_3/rel_attn/v/kernel/Adam:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.443441 47630971126400 model_utils.py:91]   name = model/transformer/layer_3/rel_attn/v/kernel/Adam_1:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.443544 47630971126400 model_utils.py:91]   name = model/transformer/layer_3/rel_attn/r/kernel/Adam:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.443648 47630971126400 model_utils.py:91]   name = model/transformer/layer_3/rel_attn/r/kernel/Adam_1:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.443749 47630971126400 model_utils.py:91]   name = model/transformer/layer_3/rel_attn/q/kernel/Adam:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.443857 47630971126400 model_utils.py:91]   name = model/transformer/layer_3/rel_attn/q/kernel/Adam_1:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.443960 47630971126400 model_utils.py:91]   name = model/transformer/layer_3/rel_attn/o/kernel/Adam:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.444062 47630971126400 model_utils.py:91]   name = model/transformer/layer_3/rel_attn/o/kernel/Adam_1:0, shape = (768, 12, 64), *INIT_FROM_CKPT*
# I1225 13:55:49.444165 47630971126400 model_utils.py:91]   name = model/transformer/layer_3/rel_attn/LayerNorm/beta/Adam:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.444261 47630971126400 model_utils.py:91]   name = model/transformer/layer_3/rel_attn/LayerNorm/beta/Adam_1:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.444357 47630971126400 model_utils.py:91]   name = model/transformer/layer_3/rel_attn/LayerNorm/gamma/Adam:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.444452 47630971126400 model_utils.py:91]   name = model/transformer/layer_3/rel_attn/LayerNorm/gamma/Adam_1:0, shape = (768,), *INIT_FROM_CKPT*
# I1225 13:55:49.444548 47630971126400 model_utils.py:91]   name = model/transformer/layer_3/ff/layer_1/kernel/Adam:0, shape = (768, 3072), *INIT_FROM_CKPT*
# ...
#     res_idx = child.expect_list(patterns, self.read_timeout)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/pexpect-4.3.1-py3.6.egg/pexpect/spawnbase.py", line 355, in expect_list
#     return exp.expect_loop(timeout)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/pexpect-4.3.1-py3.6.egg/pexpect/expect.py", line 96, in expect_loop
#     incoming = spawn.read_nonblocking(spawn.maxread, timeout)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/pexpect-4.3.1-py3.6.egg/pexpect/pty_spawn.py", line 456, in read_nonblocking
#     r, w, e = select_ignore_interrupts([self.child_fd], [], [], timeout)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/pexpect-4.3.1-py3.6.egg/pexpect/utils.py", line 143, in select_ignore_interrupts
#     return select.select(iwtd, owtd, ewtd, timeout)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/ipython-6.2.1-py3.6.egg/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-b3684fab0c96>", line 1, in <module>
#     get_ipython().system('python train_gpu.py     --record_info_dir=/scratch/kh2383/MechVent/data/xlnet_tfrecord_total/tfrecords/     --model_dir=/scratch/kh2383/MechVent/model/xlnet_model/     --init_checkpoint=/scratch/kh2383/MechVent/model/xlnet_model/model.ckpt     --train_batch_size=8     --seq_len=512     --reuse_len=256     --mem_len=384     --perm_size=256     --n_layer=12     --d_model=768     --d_embed=768     --n_head=12     --d_head=64     --d_inner=3072     --untie_r=True     --mask_alpha=6     --mask_beta=1     --num_predict=85     --num_hosts=1     --num_core_per_host=2     --train_steps=400000     --iterations=500     --save_steps=5000 ')
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/ipython-6.2.1-py3.6.egg/IPython/core/interactiveshell.py", line 2225, in system_piped
#     self.user_ns['_exit_code'] = system(self.var_expand(cmd, depth=1))
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/ipython-6.2.1-py3.6.egg/IPython/utils/_process_posix.py", line 185, in system
#     child.terminate(force=True)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/pexpect-4.3.1-py3.6.egg/pexpect/pty_spawn.py", line 607, in terminate
#     time.sleep(self.delayafterterminate)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/ipython-6.2.1-py3.6.egg/IPython/core/interactiveshell.py", line 1828, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/ipython-6.2.1-py3.6.egg/IPython/core/ultratb.py", line 1090, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/ipython-6.2.1-py3.6.egg/IPython/core/ultratb.py", line 311, in wrapped
#     return f(*args, **kwargs)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/ipython-6.2.1-py3.6.egg/IPython/core/ultratb.py", line 345, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/inspect.py", line 1480, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/inspect.py", line 1438, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/inspect.py", line 693, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/inspect.py", line 736, in getmodule
#     f = getabsfile(module)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/inspect.py", line 705, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/inspect.py", line 690, in getsourcefile
#     if os.path.exists(filename):
#   File "/home/kh2383/pytorch-gpu/py3.6.3/lib/python3.6/genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/ipython-6.2.1-py3.6.egg/IPython/utils/_process_posix.py", line 161, in system
#     res_idx = child.expect_list(patterns, self.read_timeout)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/pexpect-4.3.1-py3.6.egg/pexpect/spawnbase.py", line 355, in expect_list
#     return exp.expect_loop(timeout)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/pexpect-4.3.1-py3.6.egg/pexpect/expect.py", line 96, in expect_loop
#     incoming = spawn.read_nonblocking(spawn.maxread, timeout)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/pexpect-4.3.1-py3.6.egg/pexpect/pty_spawn.py", line 456, in read_nonblocking
#     r, w, e = select_ignore_interrupts([self.child_fd], [], [], timeout)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/pexpect-4.3.1-py3.6.egg/pexpect/utils.py", line 143, in select_ignore_interrupts
#     return select.select(iwtd, owtd, ewtd, timeout)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/ipython-6.2.1-py3.6.egg/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-b3684fab0c96>", line 1, in <module>
#     get_ipython().system('python train_gpu.py     --record_info_dir=/scratch/kh2383/MechVent/data/xlnet_tfrecord_total/tfrecords/     --model_dir=/scratch/kh2383/MechVent/model/xlnet_model/     --init_checkpoint=/scratch/kh2383/MechVent/model/xlnet_model/model.ckpt     --train_batch_size=8     --seq_len=512     --reuse_len=256     --mem_len=384     --perm_size=256     --n_layer=12     --d_model=768     --d_embed=768     --n_head=12     --d_head=64     --d_inner=3072     --untie_r=True     --mask_alpha=6     --mask_beta=1     --num_predict=85     --num_hosts=1     --num_core_per_host=2     --train_steps=400000     --iterations=500     --save_steps=5000 ')
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/ipython-6.2.1-py3.6.egg/IPython/core/interactiveshell.py", line 2225, in system_piped
#     self.user_ns['_exit_code'] = system(self.var_expand(cmd, depth=1))
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/ipython-6.2.1-py3.6.egg/IPython/utils/_process_posix.py", line 185, in system
#     child.terminate(force=True)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/pexpect-4.3.1-py3.6.egg/pexpect/pty_spawn.py", line 607, in terminate
#     time.sleep(self.delayafterterminate)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/ipython-6.2.1-py3.6.egg/IPython/core/interactiveshell.py", line 1828, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/ipython-6.2.1-py3.6.egg/IPython/core/interactiveshell.py", line 2856, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/ipython-6.2.1-py3.6.egg/IPython/core/interactiveshell.py", line 2927, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/ipython-6.2.1-py3.6.egg/IPython/core/interactiveshell.py", line 1831, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/ipython-6.2.1-py3.6.egg/IPython/core/ultratb.py", line 1371, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/ipython-6.2.1-py3.6.egg/IPython/core/ultratb.py", line 1279, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/ipython-6.2.1-py3.6.egg/IPython/core/ultratb.py", line 1140, in structured_traceback
#     formatted_exceptions += self.prepare_chained_exception_message(evalue.__cause__)
# TypeError: must be str, not list
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/ipython-6.2.1-py3.6.egg/IPython/core/interactiveshell.py", line 1828, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/ipython-6.2.1-py3.6.egg/IPython/core/ultratb.py", line 1090, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/ipython-6.2.1-py3.6.egg/IPython/core/ultratb.py", line 311, in wrapped
#     return f(*args, **kwargs)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/ipython-6.2.1-py3.6.egg/IPython/core/ultratb.py", line 345, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/inspect.py", line 1480, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/inspect.py", line 1438, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/inspect.py", line 693, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/inspect.py", line 736, in getmodule
#     f = getabsfile(module)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/inspect.py", line 705, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/inspect.py", line 690, in getsourcefile
#     if os.path.exists(filename):
#   File "/home/kh2383/pytorch-gpu/py3.6.3/lib/python3.6/genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/ipython-6.2.1-py3.6.egg/IPython/utils/_process_posix.py in system(self, cmd)
#     160                 # know whether we've finished (if we matched EOF) or not
# --> 161                 res_idx = child.expect_list(patterns, self.read_timeout)
#     162                 print(child.before[out_size:].decode(enc, 'replace'), end='')
#
# /share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/pexpect-4.3.1-py3.6.egg/pexpect/spawnbase.py in expect_list(self, pattern_list, timeout, searchwindowsize, async_, **kw)
#     354         else:
# --> 355             return exp.expect_loop(timeout)
#     356
#
# /share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/pexpect-4.3.1-py3.6.egg/pexpect/expect.py in expect_loop(self, timeout)
#      95                 # Still have time left, so read more data
# ---> 96                 incoming = spawn.read_nonblocking(spawn.maxread, timeout)
#      97                 if self.spawn.delayafterread is not None:
#
# /share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/pexpect-4.3.1-py3.6.egg/pexpect/pty_spawn.py in read_nonblocking(self, size, timeout)
#     455
# --> 456         r, w, e = select_ignore_interrupts([self.child_fd], [], [], timeout)
#     457
#
# /share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/pexpect-4.3.1-py3.6.egg/pexpect/utils.py in select_ignore_interrupts(iwtd, owtd, ewtd, timeout)
#     142         try:
# --> 143             return select.select(iwtd, owtd, ewtd, timeout)
#     144         except InterruptedError:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/ipython-6.2.1-py3.6.egg/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    1827                         # in the engines. This should return a list of strings.
# -> 1828                         stb = value._render_traceback_()
#    1829                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/ipython-6.2.1-py3.6.egg/IPython/core/interactiveshell.py in run_code(self, code_obj, result)
#    2925             if result is not None:
#    2926                 result.error_in_exec = sys.exc_info()[1]
# -> 2927             self.showtraceback(running_compiled_code=True)
#    2928         else:
#    2929             outflag = False
#
# /share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/ipython-6.2.1-py3.6.egg/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    1829                     except Exception:
#    1830                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 1831                                             value, tb, tb_offset=tb_offset)
#    1832
#    1833                     self._showtraceback(etype, value, stb)
#
# /share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/ipython-6.2.1-py3.6.egg/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369         self.tb = tb
#    1370         return FormattedTB.structured_traceback(
# -> 1371             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1372
#    1373
#
# /share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/ipython-6.2.1-py3.6.egg/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1277             # Verbose modes need a full traceback
#    1278             return VerboseTB.structured_traceback(
# -> 1279                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1280             )
#    1281         else:
#
# /share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/ipython-6.2.1-py3.6.egg/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1138             exception = self.get_parts_of_chained_exception(evalue)
#    1139             if exception:
# -> 1140                 formatted_exceptions += self.prepare_chained_exception_message(evalue.__cause__)
#    1141                 etype, evalue, etb = exception
#    1142             else:
#
# TypeError: must be str, not list
